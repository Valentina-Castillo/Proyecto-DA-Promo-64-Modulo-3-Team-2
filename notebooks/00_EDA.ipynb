# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = "../data/raw/hr.csv"
df = pd.read_csv(path)

# %%
def eda_revision_completa(df):
    """
    Realiza una revisión exploratoria estructurada del DataFrame con foco en:

    1. Visión general del dataset (dimensiones y duplicados)
    2. Calidad de columnas (tipos, nulos, cardinalidad)
    3. Análisis detallado de nulos:
        - Variables categóricas con nulos:
            * % de nulos visible en el encabezado
            * Distribución porcentual y recuento de categorías
        - Variables numéricas con nulos:
            * % de nulos visible en el encabezado
            * Distribución porcentual y recuento de valores
            * Histogramas
    4. Estadísticas descriptivas:
        - Describe de variables numéricas
        - Describe de variables categóricas
    5. Detección de outliers (IQR)
    6. Correlaciones entre variables numéricas
    7. Alertas estructurales (constantes, casi constantes, posibles IDs)
    8. Detección de variables que comparten una escala ordinal común
       y sugerencia de mapeo semántico

    El objetivo es facilitar decisiones de limpieza, imputación
    y entendimiento del dataset antes de modelar.
    """

    filas, columnas = df.shape

    # ==================================================
    # 1. VISIÓN GENERAL
    # ==================================================
    print("📐 VISIÓN GENERAL DEL DATASET")
    print(f"Filas: {filas} | Columnas: {columnas}")
    duplicados = df.duplicated().sum()
    print(f"Filas duplicadas: {duplicados} ({duplicados/filas*100:.2f}%)")
    print("-"*70)

    # ==================================================
    # 2. CALIDAD DE COLUMNAS
    # ==================================================
    print("🚑 CALIDAD DE COLUMNAS")
    calidad = pd.DataFrame({
        "Tipo": df.dtypes,
        "Nulos": df.isnull().sum(),
        "% Nulos": (df.isnull().mean()*100).round(2),
        "Valores Únicos": df.nunique(),
        "% Cardinalidad": (df.nunique()/filas*100).round(2)
    }).sort_values("% Nulos", ascending=False)

    display(calidad)

    # ==================================================
    # 3. NULOS – VARIABLES CATEGÓRICAS
    # ==================================================
    cols_cat = df.select_dtypes(include=["object", "category"]).columns
    cols_cat_nulos = [c for c in cols_cat if df[c].isnull().any()]

    print("\n🔤 NULOS EN VARIABLES CATEGÓRICAS")
    if cols_cat_nulos:
        for col in cols_cat_nulos:
            pct_nulos = df[col].isnull().mean() * 100
            print(f"\n📌 {col} (Nulos: {pct_nulos:.2f}%)")

            dist_pct = df[col].value_counts(normalize=True, dropna=False) * 100
            dist_cnt = df[col].value_counts(dropna=False)

            display(pd.DataFrame({
                "Porcentaje": dist_pct.round(2),
                "Recuento": dist_cnt
            }))
    else:
        print("No hay variables categóricas con nulos.")

    # ==================================================
    # 4. NULOS – VARIABLES NUMÉRICAS
    # ==================================================
    num_cols = df.select_dtypes(include=["int64", "float64"]).columns
    cols_num_nulos = [c for c in num_cols if df[c].isnull().any()]

    print("\n📊 NULOS EN VARIABLES NUMÉRICAS")
    if cols_num_nulos:
        for col in cols_num_nulos:
            pct_nulos = df[col].isnull().mean() * 100
            print(f"\n📌 {col} (Nulos: {pct_nulos:.2f}%)")

            dist_pct = df[col].value_counts(normalize=True, dropna=False) * 100
            dist_cnt = df[col].value_counts(dropna=False)

            display(pd.DataFrame({
                "Porcentaje": dist_pct.round(2),
                "Recuento": dist_cnt
            }))

            # Histograma
            plt.figure()
            df[col].hist(bins=30)
            plt.title(f"Histograma de {col}")
            plt.xlabel(col)
            plt.ylabel("Frecuencia")
            plt.show()
    else:
        print("No hay variables numéricas con nulos.")

    # ==================================================
    # 5. ESTADÍSTICAS DESCRIPTIVAS
    # ==================================================
    print("\n📊 DESCRIBE VARIABLES NUMÉRICAS")
    if len(num_cols) > 0:
        display(df[num_cols].describe().T)

    print("\n🔤 DESCRIBE VARIABLES CATEGÓRICAS")
    if len(cols_cat) > 0:
        display(df[cols_cat].describe().T)

    print("\n📝 ANÁLISIS DE CATEGORÍAS ÚNICAS DE TODAS LAS VARIABLES OBJECT")
    cols_cat = df.select_dtypes(include=["object", "category"]).columns

    for col in cols_cat:
        print(f"\n📌 {col} - Categorías actuales ({df[col].nunique()} únicas):")
        display(pd.DataFrame(df[col].unique(), columns=['Valor único']))

    # ==================================================
    # 6. DETECCIÓN DE OUTLIERS (IQR)
    # ==================================================
    print("\n⚠️ DETECCIÓN DE OUTLIERS (IQR 1.5x)")
    for col in num_cols:
        Q1, Q3 = df[col].quantile([0.25, 0.75])
        IQR = Q3 - Q1
        outliers = ((df[col] < Q1 - 1.5*IQR) |
                    (df[col] > Q3 + 1.5*IQR)).sum()
        if outliers > 0:
            print(f"- {col}: {outliers} outliers ({outliers/filas*100:.2f}%)")

    # ==================================================
    # 7. CORRELACIONES
    # ==================================================
    print("\n🔗 CORRELACIONES ENTRE VARIABLES NUMÉRICAS")
    if len(num_cols) > 1:
        corr = df[num_cols].corr()
        display(corr)

        high_corr = (
            corr.abs()
            .where(np.triu(np.ones(corr.shape), k=1).astype(bool))
            .stack()
            .sort_values(ascending=False)
        )

        if not high_corr.empty:
            print("\n⚠️ Correlaciones altas (>0.8)")
            display(high_corr[high_corr > 0.8])

    # ==================================================
    # 8. ALERTAS ESTRUCTURALES
    # ==================================================
    print("\n🚨 ALERTAS ESTRUCTURALES")

    constantes = calidad[calidad["Valores Únicos"] == 1].index.tolist()
    if constantes:
        print(f"⚠️ Columnas constantes: {constantes}")

    casi_constantes = []
    for col in df.columns:
        vc = df[col].value_counts(normalize=True, dropna=False)
        if not vc.empty and vc.iloc[0] > 0.95:
            casi_constantes.append(col)

    if casi_constantes:
        print(f"⚠️ Columnas casi constantes (>95% mismo valor): {casi_constantes}")

    posibles_ids = calidad[calidad["% Cardinalidad"] > 95].index.tolist()
    if posibles_ids:
        print(f"🆔 Posibles IDs o identificadores: {posibles_ids}")

    # ==================================================
    # 9. ESCALAS ORDINALES COMPARTIDAS
    # ==================================================
    print("\n💡 DETECCIÓN DE ESCALAS ORDINALES COMPARTIDAS")

    escala_comun = {
        1: "Nada satisfecho",
        2: "Insatisfecho",
        3: "Satisfecho",
        4: "Muy Satisfecho"
    }

    cols_ordinales = [
        col for col in num_cols
        if set(df[col].dropna().unique()).issubset(set(escala_comun.keys()))
    ]

    if cols_ordinales:
        print(f"Columnas que siguen la misma escala: {cols_ordinales}")
        print("Escala sugerida:")
        for k, v in escala_comun.items():
            print(f"{k} → {v}")
    else:
        print("No se detectaron columnas con la escala ordinal definida.")

    print("\n🏁 REVISIÓN EDA FINALIZADA")

# %%
eda_revision_completa(df)
# Out:
# 📐 VISIÓN GENERAL DEL DATASET
# Filas: 1474 | Columnas: 35
# Filas duplicadas: 4 (0.27%)
# ----------------------------------------------------------------------
# 🚑 CALIDAD DE COLUMNAS
#                              Tipo  Nulos  % Nulos  Valores Únicos  \
# StandardHours             float64    164    11.13               1
# YearsWithCurrManager      float64    148    10.04              18
# MaritalStatus              object    132     8.96               4
# BusinessTravel             object    117     7.94               3
# TrainingTimesLastYear     float64     88     5.97               7
# Age                       float64     73     4.95              43
# EducationField             object     58     3.93               6
# OverTime                   object     44     2.99               2
# JobSatisfaction           float64     29     1.97               4
# Department                 object     29     1.97               3
# MonthlyIncome             float64     14     0.95            1336
# Attrition                  object      0     0.00               2
# EmployeeNumber              int64      0     0.00            1470
# EmployeeCount               int64      0     0.00               1
# Gender                     object      0     0.00               2
# EnvironmentSatisfaction     int64      0     0.00               4
# Education                   int64      0     0.00               5
# DistanceFromHome            int64      0     0.00              29
# DailyRate                   int64      0     0.00             886
# JobRole                    object      0     0.00               9
# HourlyRate                  int64      0     0.00              71
# JobInvolvement              int64      0     0.00               4
# JobLevel                    int64      0     0.00               5
# Over18                     object      0     0.00               1
# PercentSalaryHike           int64      0     0.00              15
# NumCompaniesWorked          int64      0     0.00              10
# MonthlyRate                 int64      0     0.00            1427
# RelationshipSatisfaction    int64      0     0.00               4
# PerformanceRating           int64      0     0.00               2
# TotalWorkingYears           int64      0     0.00              40
# StockOptionLevel            int64      0     0.00               4
# WorkLifeBalance             int64      0     0.00               4
# YearsAtCompany              int64      0     0.00              37
# YearsInCurrentRole          int64      0     0.00              19
# YearsSinceLastPromotion     int64      0     0.00              16
#
#                           % Cardinalidad
# StandardHours                       0.07
# YearsWithCurrManager                1.22
# MaritalStatus                       0.27
# BusinessTravel                      0.20
# TrainingTimesLastYear               0.47
# Age                                 2.92
# EducationField                      0.41
# OverTime                            0.14
# JobSatisfaction                     0.27
# Department                          0.20
# MonthlyIncome                      90.64
# Attrition                           0.14
# EmployeeNumber                     99.73
# EmployeeCount                       0.07
# Gender                              0.14
# EnvironmentSatisfaction             0.27
# Education                           0.34
# DistanceFromHome                    1.97
# DailyRate                          60.11
# JobRole                             0.61
# HourlyRate                          4.82
# JobInvolvement                      0.27
# JobLevel                            0.34
# Over18                              0.07
# PercentSalaryHike                   1.02
# NumCompaniesWorked                  0.68
# MonthlyRate                        96.81
# RelationshipSatisfaction            0.27
# PerformanceRating                   0.14
# TotalWorkingYears                   2.71
# StockOptionLevel                    0.27
# WorkLifeBalance                     0.27
# YearsAtCompany                      2.51
# YearsInCurrentRole                  1.29
# YearsSinceLastPromotion             1.09
# 🔤 NULOS EN VARIABLES CATEGÓRICAS
#
# 📌 BusinessTravel (Nulos: 7.94%)
#                    Porcentaje  Recuento
# BusinessTravel
# Travel_Rarely           64.79       955
# Travel_Frequently       17.84       263
# Non-Travel               9.43       139
# NaN                      7.94       117
# 📌 Department (Nulos: 1.97%)
#                         Porcentaje  Recuento
# Department
# Research & Development       63.84       941
# Sales                        29.85       440
# Human Resources               4.34        64
# NaN                           1.97        29
# 📌 EducationField (Nulos: 3.93%)
#                   Porcentaje  Recuento
# EducationField
# Life Sciences          39.48       582
# Medical                30.46       449
# Marketing              10.31       152
# Technical Degree        8.82       130
# Other                   5.36        79
# NaN                     3.93        58
# Human Resources         1.63        24
# 📌 MaritalStatus (Nulos: 8.96%)
#                Porcentaje  Recuento
# MaritalStatus
# Married             40.98       604
# Single              29.65       437
# Divorced            20.22       298
# NaN                  8.96       132
# Marreid              0.20         3
# 📌 OverTime (Nulos: 2.99%)
#           Porcentaje  Recuento
# OverTime
# No             69.54      1025
# Yes            27.48       405
# NaN             2.99        44
# 📊 NULOS EN VARIABLES NUMÉRICAS
#
# 📌 Age (Nulos: 4.95%)
#       Porcentaje  Recuento
# Age
# 35.0        4.95        73
# NaN         4.95        73
# 34.0        4.88        72
# 36.0        4.61        68
# 29.0        4.41        65
# 31.0        4.27        63
# 32.0        4.00        59
# 30.0        3.87        57
# 33.0        3.87        57
# 40.0        3.80        56
# 38.0        3.66        54
# 37.0        3.39        50
# 27.0        3.26        48
# 28.0        3.12        46
# 45.0        2.78        41
# 39.0        2.78        41
# 42.0        2.78        41
# 41.0        2.65        39
# 26.0        2.44        36
# 44.0        2.17        32
# 46.0        2.17        32
# 43.0        2.04        30
# 50.0        1.83        27
# 47.0        1.63        24
# 24.0        1.63        24
# 25.0        1.56        23
# 49.0        1.49        22
# 55.0        1.42        21
# 53.0        1.29        19
# 48.0        1.22        18
# 51.0        1.22        18
# 52.0        1.15        17
# 54.0        1.09        16
# 22.0        1.09        16
# 56.0        0.95        14
# 58.0        0.88        13
# 23.0        0.88        13
# 21.0        0.75        11
# 20.0        0.75        11
# 59.0        0.61         9
# 18.0        0.54         8
# 19.0        0.54         8
# 60.0        0.34         5
# 57.0        0.27         4
# 📌 JobSatisfaction (Nulos: 1.97%)
#                  Porcentaje  Recuento
# JobSatisfaction
# 4.0                   30.87       455
# 3.0                   29.10       429
# 1.0                   19.40       286
# 2.0                   18.66       275
# NaN                    1.97        29
# 📌 MonthlyIncome (Nulos: 0.95%)
#                Porcentaje  Recuento
# MonthlyIncome
# NaN                  0.95        14
# 2342.0               0.27         4
# 2451.0               0.20         3
# 2404.0               0.20         3
# 2380.0               0.20         3
# ...                   ...       ...
# 13570.0              0.07         1
# 6712.0               0.07         1
# 5406.0               0.07         1
# 8938.0               0.07         1
# 10422.0              0.07         1
#
# [1337 rows x 2 columns]
# 📌 StandardHours (Nulos: 11.13%)
#                Porcentaje  Recuento
# StandardHours
# 80.0                88.87      1310
# NaN                 11.13       164
# 📌 TrainingTimesLastYear (Nulos: 5.97%)
#                        Porcentaje  Recuento
# TrainingTimesLastYear
# 2.0                         35.28       520
# 3.0                         30.94       456
# 4.0                          8.01       118
# 5.0                          7.53       111
# NaN                          5.97        88
# 1.0                          4.41        65
# 6.0                          4.27        63
# 0.0                          3.60        53
# 📌 YearsWithCurrManager (Nulos: 10.04%)
#                       Porcentaje  Recuento
# YearsWithCurrManager
# 2.0                        21.85       322
# 0.0                        16.01       236
# 7.0                        13.16       194
# NaN                        10.04       148
# 3.0                         8.41       124
# 8.0                         6.72        99
# 4.0                         6.04        89
# 1.0                         4.68        69
# 9.0                         3.73        55
# 5.0                         1.97        29
# 6.0                         1.83        27
# 11.0                        1.49        22
# 10.0                        1.36        20
# 13.0                        0.81        12
# 12.0                        0.81        12
# 17.0                        0.47         7
# 15.0                        0.27         4
# 14.0                        0.27         4
# 16.0                        0.07         1
# 📊 DESCRIBE VARIABLES NUMÉRICAS
#                            count          mean          std     min      25%  \
# Age                       1401.0     36.944325     9.105009    18.0    30.00
# DailyRate                 1474.0    802.702171   403.539530   102.0   465.00
# DistanceFromHome          1474.0      9.199457     8.104266     1.0     2.00
# Education                 1474.0      2.911126     1.024267     1.0     2.00
# EmployeeCount             1474.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1474.0   1024.471506   602.421193     1.0   488.75
# EnvironmentSatisfaction   1474.0      2.723881     1.093280     1.0     2.00
# HourlyRate                1474.0     65.887381    20.310444    30.0    48.00
# JobInvolvement            1474.0      2.729986     0.712861     1.0     2.00
# JobLevel                  1474.0      2.063772     1.106055     1.0     1.00
# JobSatisfaction           1445.0      2.728720     1.106409     1.0     2.00
# MonthlyIncome             1460.0   6497.448630  4706.059294  1009.0  2909.00
# MonthlyRate               1474.0  14328.611940  7120.225285  2094.0  8054.50
# NumCompaniesWorked        1474.0      2.688602     2.496443     0.0     1.00
# PercentSalaryHike         1474.0     15.206920     3.659274    11.0    12.00
# PerformanceRating         1474.0      3.153324     0.360422     3.0     3.00
# RelationshipSatisfaction  1474.0      2.713704     1.080338     1.0     2.00
# StandardHours             1310.0     80.000000     0.000000    80.0    80.00
# StockOptionLevel          1474.0      0.794437     0.851784     0.0     0.00
# TotalWorkingYears         1474.0     11.274084     7.785972     0.0     6.00
# TrainingTimesLastYear     1386.0      2.797980     1.296882     0.0     2.00
# WorkLifeBalance           1474.0      2.761872     0.705625     1.0     2.00
# YearsAtCompany            1474.0      6.996608     6.122920     0.0     3.00
# YearsInCurrentRole        1474.0      4.221845     3.622032     0.0     2.00
# YearsSinceLastPromotion   1474.0      2.183175     3.219356     0.0     0.00
# YearsWithCurrManager      1326.0      4.061840     3.517603     0.0     2.00
#
#                               50%       75%      max
# Age                          36.0     43.00     60.0
# DailyRate                   803.0   1157.00   1499.0
# DistanceFromHome              7.0     14.00     29.0
# Education                     3.0      4.00      5.0
# EmployeeCount                 1.0      1.00      1.0
# EmployeeNumber             1020.5   1555.75   2068.0
# EnvironmentSatisfaction       3.0      4.00      4.0
# HourlyRate                   66.0     83.75    100.0
# JobInvolvement                3.0      3.00      4.0
# JobLevel                      2.0      3.00      5.0
# JobSatisfaction               3.0      4.00      4.0
# MonthlyIncome              4907.0   8377.00  19999.0
# MonthlyRate               14248.5  20465.75  26999.0
# NumCompaniesWorked            2.0      4.00      9.0
# PercentSalaryHike            14.0     18.00     25.0
# PerformanceRating             3.0      3.00      4.0
# RelationshipSatisfaction      3.0      4.00      4.0
# StandardHours                80.0     80.00     80.0
# StockOptionLevel              1.0      1.00      3.0
# TotalWorkingYears            10.0     15.00     40.0
# TrainingTimesLastYear         3.0      3.00      6.0
# WorkLifeBalance               3.0      3.00      4.0
# YearsAtCompany                5.0      9.00     40.0
# YearsInCurrentRole            3.0      7.00     18.0
# YearsSinceLastPromotion       1.0      3.00     15.0
# YearsWithCurrManager          3.0      7.00     17.0
# 🔤 DESCRIBE VARIABLES CATEGÓRICAS
#                count unique                     top  freq
# Attrition       1474      2                      No  1236
# BusinessTravel  1357      3           Travel_Rarely   955
# Department      1445      3  Research & Development   941
# EducationField  1416      6           Life Sciences   582
# Gender          1474      2                    Male   885
# JobRole         1474      9        sALES eXECUTIVE    327
# MaritalStatus   1342      4                 Married   604
# Over18          1474      1                       Y  1474
# OverTime        1430      2                      No  1025
# 📝 ANÁLISIS DE CATEGORÍAS ÚNICAS DE TODAS LAS VARIABLES OBJECT
#
# 📌 Attrition - Categorías actuales (2 únicas):
#   Valor único
# 0         Yes
# 1          No
# 📌 BusinessTravel - Categorías actuales (3 únicas):
#          Valor único
# 0      Travel_Rarely
# 1  Travel_Frequently
# 2         Non-Travel
# 3                NaN
# 📌 Department - Categorías actuales (3 únicas):
#               Valor único
# 0                   Sales
# 1  Research & Development
# 2                     NaN
# 3         Human Resources
# 📌 EducationField - Categorías actuales (6 únicas):
#         Valor único
# 0     Life Sciences
# 1             Other
# 2           Medical
# 3               NaN
# 4         Marketing
# 5  Technical Degree
# 6   Human Resources
# 📌 Gender - Categorías actuales (2 únicas):
#   Valor único
# 0      Female
# 1        Male
# 📌 JobRole - Categorías actuales (9 únicas):
#                    Valor único
# 0             sALES eXECUTIVE
# 1          rESEARCH sCIENTIST
# 2       lABORATORY tECHNICIAN
# 3      mANUFACTURING dIRECTOR
# 4   hEALTHCARE rEPRESENTATIVE
# 5                     mANAGER
# 6        sALES rEPRESENTATIVE
# 7           rESEARCH dIRECTOR
# 8             hUMAN rESOURCES
# 📌 MaritalStatus - Categorías actuales (4 únicas):
#   Valor único
# 0      Single
# 1     Married
# 2    Divorced
# 3         NaN
# 4     Marreid
# 📌 Over18 - Categorías actuales (1 únicas):
#   Valor único
# 0           Y
# 📌 OverTime - Categorías actuales (2 únicas):
#   Valor único
# 0         Yes
# 1          No
# 2         NaN
# ⚠️ DETECCIÓN DE OUTLIERS (IQR 1.5x)
# - MonthlyIncome: 113 outliers (7.67%)
# - NumCompaniesWorked: 52 outliers (3.53%)
# - PerformanceRating: 226 outliers (15.33%)
# - StockOptionLevel: 85 outliers (5.77%)
# - TotalWorkingYears: 63 outliers (4.27%)
# - TrainingTimesLastYear: 227 outliers (15.40%)
# - YearsAtCompany: 104 outliers (7.06%)
# - YearsInCurrentRole: 21 outliers (1.42%)
# - YearsSinceLastPromotion: 107 outliers (7.26%)
# - YearsWithCurrManager: 12 outliers (0.81%)
#
# 🔗 CORRELACIONES ENTRE VARIABLES NUMÉRICAS
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.012928         -0.003047   0.197619
# DailyRate                 0.012928   1.000000         -0.006546  -0.015326
# DistanceFromHome         -0.003047  -0.006546          1.000000   0.018657
# Education                 0.197619  -0.015326          0.018657   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.015103  -0.053834          0.033661   0.041203
# EnvironmentSatisfaction   0.011139   0.017276         -0.014698  -0.029204
# HourlyRate                0.019332   0.023287          0.030278   0.017532
# JobInvolvement            0.021280   0.049445          0.006508   0.044284
# JobLevel                  0.504765   0.004601          0.004109   0.102684
# JobSatisfaction          -0.029089   0.025987         -0.003060  -0.008267
# MonthlyIncome             0.490315   0.006213         -0.019003   0.098333
# MonthlyRate               0.036711  -0.030221          0.026951  -0.026416
# NumCompaniesWorked        0.303524   0.038027         -0.029712   0.127229
# PercentSalaryHike         0.002744   0.023712          0.038188  -0.008856
# PerformanceRating         0.006087   0.000244          0.026710  -0.023749
# RelationshipSatisfaction  0.038351   0.008072          0.006449  -0.009512
# StandardHours                  NaN        NaN               NaN        NaN
# StockOptionLevel          0.040620   0.042600          0.045773   0.017174
# TotalWorkingYears         0.673863   0.016850          0.002856   0.149987
# TrainingTimesLastYear    -0.027412   0.021125         -0.033384  -0.032528
# WorkLifeBalance          -0.020006  -0.037607         -0.026235   0.009210
# YearsAtCompany            0.298187  -0.034204          0.008578   0.070422
# YearsInCurrentRole        0.205234   0.009661          0.017595   0.061863
# YearsSinceLastPromotion   0.203265  -0.033352          0.009423   0.055175
# YearsWithCurrManager      0.207117  -0.042303          0.023442   0.074195
#
#                           EmployeeCount  EmployeeNumber  \
# Age                                 NaN       -0.015103
# DailyRate                           NaN       -0.053834
# DistanceFromHome                    NaN        0.033661
# Education                           NaN        0.041203
# EmployeeCount                       NaN             NaN
# EmployeeNumber                      NaN        1.000000
# EnvironmentSatisfaction             NaN        0.018730
# HourlyRate                          NaN        0.035979
# JobInvolvement                      NaN       -0.010504
# JobLevel                            NaN       -0.020093
# JobSatisfaction                     NaN       -0.043563
# MonthlyIncome                       NaN       -0.012935
# MonthlyRate                         NaN        0.010821
# NumCompaniesWorked                  NaN       -0.001429
# PercentSalaryHike                   NaN       -0.012928
# PerformanceRating                   NaN       -0.020034
# RelationshipSatisfaction            NaN       -0.069392
# StandardHours                       NaN             NaN
# StockOptionLevel                    NaN        0.060268
# TotalWorkingYears                   NaN       -0.016833
# TrainingTimesLastYear               NaN        0.025670
# WorkLifeBalance                     NaN        0.010066
# YearsAtCompany                      NaN       -0.010669
# YearsInCurrentRole                  NaN       -0.007557
# YearsSinceLastPromotion             NaN       -0.008669
# YearsWithCurrManager                NaN       -0.012592
#
#                           EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# Age                                      0.011139    0.019332        0.021280
# DailyRate                                0.017276    0.023287        0.049445
# DistanceFromHome                        -0.014698    0.030278        0.006508
# Education                               -0.029204    0.017532        0.044284
# EmployeeCount                                 NaN         NaN             NaN
# EmployeeNumber                           0.018730    0.035979       -0.010504
# EnvironmentSatisfaction                  1.000000   -0.049555       -0.008620
# HourlyRate                              -0.049555    1.000000        0.042959
# JobInvolvement                          -0.008620    0.042959        1.000000
# JobLevel                                -0.000025   -0.027785       -0.010865
# JobSatisfaction                         -0.014877   -0.065931       -0.020028
# MonthlyIncome                           -0.009573   -0.016971       -0.014882
# MonthlyRate                              0.039242   -0.015026       -0.013091
# NumCompaniesWorked                       0.010761    0.021922        0.014902
# PercentSalaryHike                       -0.033054   -0.008053       -0.016304
# PerformanceRating                       -0.030318   -0.002091       -0.029004
# RelationshipSatisfaction                 0.008896    0.001840        0.034427
# StandardHours                                 NaN         NaN             NaN
# StockOptionLevel                         0.003890    0.049087        0.022569
# TotalWorkingYears                       -0.005698   -0.002557       -0.004026
# TrainingTimesLastYear                   -0.027620   -0.010716       -0.004510
# WorkLifeBalance                          0.028233   -0.004667       -0.014542
# YearsAtCompany                           0.000468   -0.019126       -0.020585
# YearsInCurrentRole                       0.017023   -0.023349        0.009543
# YearsSinceLastPromotion                  0.015344   -0.026472       -0.023694
# YearsWithCurrManager                     0.000214   -0.036795        0.019918
#
#                           JobLevel  ...  RelationshipSatisfaction  \
# Age                       0.504765  ...                  0.038351
# DailyRate                 0.004601  ...                  0.008072
# DistanceFromHome          0.004109  ...                  0.006449
# Education                 0.102684  ...                 -0.009512
# EmployeeCount                  NaN  ...                       NaN
# EmployeeNumber           -0.020093  ...                 -0.069392
# EnvironmentSatisfaction  -0.000025  ...                  0.008896
# HourlyRate               -0.027785  ...                  0.001840
# JobInvolvement           -0.010865  ...                  0.034427
# JobLevel                  1.000000  ...                  0.021539
# JobSatisfaction          -0.000436  ...                 -0.014526
# MonthlyIncome             0.950176  ...                  0.028214
# MonthlyRate               0.039969  ...                 -0.002689
# NumCompaniesWorked        0.142669  ...                  0.051499
# PercentSalaryHike        -0.033623  ...                 -0.040130
# PerformanceRating        -0.021138  ...                 -0.031901
# RelationshipSatisfaction  0.021539  ...                  1.000000
# StandardHours                  NaN  ...                       NaN
# StockOptionLevel          0.013924  ...                 -0.046292
# TotalWorkingYears         0.782120  ...                  0.023379
# TrainingTimesLastYear    -0.017410  ...                  0.004420
# WorkLifeBalance           0.037738  ...                  0.020047
# YearsAtCompany            0.534136  ...                  0.018635
# YearsInCurrentRole        0.388937  ...                 -0.015681
# YearsSinceLastPromotion   0.353626  ...                  0.032851
# YearsWithCurrManager      0.373210  ...                 -0.014429
#
#                           StandardHours  StockOptionLevel  TotalWorkingYears  \
# Age                                 NaN          0.040620           0.673863
# DailyRate                           NaN          0.042600           0.016850
# DistanceFromHome                    NaN          0.045773           0.002856
# Education                           NaN          0.017174           0.149987
# EmployeeCount                       NaN               NaN                NaN
# EmployeeNumber                      NaN          0.060268          -0.016833
# EnvironmentSatisfaction             NaN          0.003890          -0.005698
# HourlyRate                          NaN          0.049087          -0.002557
# JobInvolvement                      NaN          0.022569          -0.004026
# JobLevel                            NaN          0.013924           0.782120
# JobSatisfaction                     NaN          0.014870          -0.019186
# MonthlyIncome                       NaN          0.008304           0.774789
# MonthlyRate                         NaN         -0.033395           0.025929
# NumCompaniesWorked                  NaN          0.029898           0.238126
# PercentSalaryHike                   NaN          0.005815          -0.018648
# PerformanceRating                   NaN          0.003223           0.007029
# RelationshipSatisfaction            NaN         -0.046292           0.023379
# StandardHours                       NaN               NaN                NaN
# StockOptionLevel                    NaN          1.000000           0.009832
# TotalWorkingYears                   NaN          0.009832           1.000000
# TrainingTimesLastYear               NaN          0.016643          -0.036549
# WorkLifeBalance                     NaN          0.004346           0.000767
# YearsAtCompany                      NaN          0.014445           0.626503
# YearsInCurrentRole                  NaN          0.049779           0.458963
# YearsSinceLastPromotion             NaN          0.013988           0.404041
# YearsWithCurrManager                NaN          0.026153           0.464123
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Age                                   -0.027412        -0.020006
# DailyRate                              0.021125        -0.037607
# DistanceFromHome                      -0.033384        -0.026235
# Education                             -0.032528         0.009210
# EmployeeCount                               NaN              NaN
# EmployeeNumber                         0.025670         0.010066
# EnvironmentSatisfaction               -0.027620         0.028233
# HourlyRate                            -0.010716        -0.004667
# JobInvolvement                        -0.004510        -0.014542
# JobLevel                              -0.017410         0.037738
# JobSatisfaction                       -0.015480        -0.025401
# MonthlyIncome                         -0.023317         0.029585
# MonthlyRate                            0.000023         0.008684
# NumCompaniesWorked                    -0.067644        -0.008980
# PercentSalaryHike                     -0.015313        -0.003516
# PerformanceRating                     -0.025004         0.002180
# RelationshipSatisfaction               0.004420         0.020047
# StandardHours                               NaN              NaN
# StockOptionLevel                       0.016643         0.004346
# TotalWorkingYears                     -0.036549         0.000767
# TrainingTimesLastYear                  1.000000         0.031519
# WorkLifeBalance                        0.031519         1.000000
# YearsAtCompany                         0.005634         0.011441
# YearsInCurrentRole                    -0.004955         0.049106
# YearsSinceLastPromotion               -0.000358         0.008456
# YearsWithCurrManager                  -0.005949         0.000222
#
#                           YearsAtCompany  YearsInCurrentRole  \
# Age                             0.298187            0.205234
# DailyRate                      -0.034204            0.009661
# DistanceFromHome                0.008578            0.017595
# Education                       0.070422            0.061863
# EmployeeCount                        NaN                 NaN
# EmployeeNumber                 -0.010669           -0.007557
# EnvironmentSatisfaction         0.000468            0.017023
# HourlyRate                     -0.019126           -0.023349
# JobInvolvement                 -0.020585            0.009543
# JobLevel                        0.534136            0.388937
# JobSatisfaction                -0.000475            0.001894
# MonthlyIncome                   0.517809            0.363459
# MonthlyRate                    -0.024602           -0.013725
# NumCompaniesWorked             -0.117144           -0.089508
# PercentSalaryHike              -0.035268           -0.000546
# PerformanceRating               0.004235            0.035811
# RelationshipSatisfaction        0.018635           -0.015681
# StandardHours                        NaN                 NaN
# StockOptionLevel                0.014445            0.049779
# TotalWorkingYears               0.626503            0.458963
# TrainingTimesLastYear           0.005634           -0.004955
# WorkLifeBalance                 0.011441            0.049106
# YearsAtCompany                  1.000000            0.759141
# YearsInCurrentRole              0.759141            1.000000
# YearsSinceLastPromotion         0.618790            0.548501
# YearsWithCurrManager            0.760897            0.705508
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.203265              0.207117
# DailyRate                               -0.033352             -0.042303
# DistanceFromHome                         0.009423              0.023442
# Education                                0.055175              0.074195
# EmployeeCount                                 NaN                   NaN
# EmployeeNumber                          -0.008669             -0.012592
# EnvironmentSatisfaction                  0.015344              0.000214
# HourlyRate                              -0.026472             -0.036795
# JobInvolvement                          -0.023694              0.019918
# JobLevel                                 0.353626              0.373210
# JobSatisfaction                         -0.017817             -0.012062
# MonthlyIncome                            0.344438              0.342754
# MonthlyRate                              0.000711             -0.040369
# NumCompaniesWorked                      -0.035894             -0.113637
# PercentSalaryHike                       -0.021718             -0.011000
# PerformanceRating                        0.018490              0.017685
# RelationshipSatisfaction                 0.032851             -0.014429
# StandardHours                                 NaN                   NaN
# StockOptionLevel                         0.013988              0.026153
# TotalWorkingYears                        0.404041              0.464123
# TrainingTimesLastYear                   -0.000358             -0.005949
# WorkLifeBalance                          0.008456              0.000222
# YearsAtCompany                           0.618790              0.760897
# YearsInCurrentRole                       0.548501              0.705508
# YearsSinceLastPromotion                  1.000000              0.514062
# YearsWithCurrManager                     0.514062              1.000000
#
# [26 rows x 26 columns]
# ⚠️ Correlaciones altas (>0.8)
# JobLevel  MonthlyIncome    0.950176
# dtype: float64
# 🚨 ALERTAS ESTRUCTURALES
# ⚠️ Columnas constantes: ['StandardHours', 'EmployeeCount', 'Over18']
# ⚠️ Columnas casi constantes (>95% mismo valor): ['EmployeeCount', 'Over18']
# 🆔 Posibles IDs o identificadores: ['EmployeeNumber', 'MonthlyRate']
#
# 💡 DETECCIÓN DE ESCALAS ORDINALES COMPARTIDAS
# Columnas que siguen la misma escala: ['EmployeeCount', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobSatisfaction', 'PerformanceRating', 'RelationshipSatisfaction', 'WorkLifeBalance']
# Escala sugerida:
# 1 → Nada satisfecho
# 2 → Insatisfecho
# 3 → Satisfecho
# 4 → Muy Satisfecho
#
# 🏁 REVISIÓN EDA FINALIZADA

# %% [markdown]
# ## 🧹 Decisiones de limpieza de datos
#
# A continuación se documentan las decisiones de limpieza adoptadas tras la revisión exploratoria del dataset, con el objetivo de mejorar la calidad de los datos y facilitar su uso en etapas posteriores de análisis y modelado.
#
# ---
#
# ### 📌 0. Visión general del dataset
#
# Se realizó una inspección inicial del dataset para entender su estructura y posibles problemas:
#
# - **Filas**: 1474
# - **Columnas**: 35
# - **Filas duplicadas**: 4 (0.27%)
#
# Esta visión permitió identificar duplicados, tipos de datos incorrectos y columnas con problemas de consistencia que se tratan en los apartados siguientes.
#
# ---
#
# ### 🗑 1. Eliminación de filas duplicadas
#
# - Se identificaron **4 filas duplicadas**, lo que representa aproximadamente **el 0.27% del total del dataset**.
# - Dado que los duplicados no aportan información adicional y pueden introducir sesgos en análisis estadísticos y modelos predictivos, **se decidió eliminar todas las filas duplicadas**.
#
# **Acción**:
# - Eliminar duplicados usando `df.drop_duplicates()`.
#
# ---
#
# ### 🧾 2. Revisión de la calidad de las columnas y cambio de tipos
#
# Se evaluaron **tipos de datos, nulos y cardinalidad** para cada columna y se identificaron los siguientes cambios de tipo o estandarización:
#
# - **Age** → `int64`
# - **DailyRate, HourlyRate, MonthlyRate** → `float`
# - **JobSatisfaction, TrainingTimesLastYear, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrentManager** → `int64`
# - **BusinessTravel, Department, EducationField, Gender, Attrition, OverTime, MaritalStatus, JobRole** → categóricas
# - **Education, EnvironmentSatisfaction, JobInvolvement, JobLevel, PerformanceRating, RelationshipSatisfaction, StockOptionLevel, WorkLifeBalance** → ordinal
#
# ---
#
# ### 💬 3. Tratamiento de valores nulos en variables categóricas
#
# - Variables afectadas: `BusinessTravel`, `Department`, `EducationField`, `Gender`, `MaritalStatus`, `OverTime`
# - Para cada variable se analizaron porcentaje de nulos y distribución de categorías.
# - **Decisión**:
#   - Cuando el porcentaje de nulos es bajo y existe una categoría dominante: imputar con la moda
#   - Cuando los nulos representan un grupo relevante o semánticamente distinto: crear categoría explícita `"Missing"` o `"Unknown"`
#
# ---
#
# ### 🔢 4. Tratamiento de valores nulos en variables numéricas
#
# - Variables afectadas (si aplica): `TrainingTimesLastYear`, `NumCompaniesWorked`, `TotalWorkingYears`.
# - Se evaluó el **porcentaje de nulos** y la **distribución** de cada variable antes de decidir el tratamiento.
#
# **Criterio de decisión**
# - Si el porcentaje de nulos es **bajo**, se aplica imputación con **SimpleImputer** usando una medida **robusta** (`median`) para minimizar el impacto de valores extremos.
# - Si el porcentaje de nulos es **moderado** y existen variables numéricas relacionadas que pueden aportar contexto, se puede aplicar **KNNImputer** para imputar valores en función de los registros más similares (K vecinos).
# - Si el porcentaje de nulos es **elevado**, se valora:
#   - eliminar la variable si su aporte es limitado, o
#   - crear una variable indicadora de nulos (*missingness*) si la ausencia de datos podría aportar señal relevante, y posteriormente imputar (mediana o KNN según el caso).
#
# ---
#
# ### ✍️ 5. Normalización y corrección de columnas categóricas
#
# Durante el análisis de categorías únicas se detectaron inconsistencias en la escritura y formato de texto, así como errores tipográficos.
# Se propone la siguiente normalización y homogenización, **sin considerar aún los valores nulos**:
#
# - **BusinessTravel**
#   - Observación: valores consistentes (`Travel_Rarely`, `Travel_Frequently`, `Non-Travel`).
#   - Acción: homogeneizar usando `Title Case` y eliminar espacios innecesarios. Pasar a escala (`Rarely`, `Frequently`, `Non`).
#
# - **JobRole**
#   - Observación: las categorías presentan inconsistencias en mayúsculas/minúsculas (`sALES eXECUTIVE`, `rESEARCH sCIENTIST`, etc.) y posibles espacios extra.
#   - Acción: normalizar todos los valores a formato `Title Case` y eliminar espacios al inicio o final.
#
# - **MaritalStatus**
#   - Observación: error tipográfico detectado (`Marreid`), además de inconsistencias en mayúsculas/minúsculas.
#   - Acción: corregir typo a `Married` y homogeneizar formato con `Title Case`.
#
# ---
#
# ### 🚫 6. Columnas constantes o de alta cardinalidad
#
# - Columnas **constantes** eliminadas: `EmployeeCount`, `Over18`, `StandardHours`
# - Columnas con **alta cardinalidad (>95%)** eliminadas: `MonthlyRate` (excluida del análisis predictivo)
#
# ---
#
# ### 🆔 7. Variables identificadas como posibles IDs
#
# - `EmployeeNumber` se establece como **índice del DataFrame** y se excluye de los modelos predictivos.
#
# ---
#
# ### ⚠️ 8. Detección y tratamiento de outliers en variables numéricas
#
# - Se utilizaron criterios de **IQR (1.5x)** para detectar outliers.
# - Ejemplos de detección por variable (valores extremos detectados):
#   - `DailyRate`: valores <100 o >1400
#   - `MonthlyIncome`: valores >17000
#   - `DistanceFromHome`: valores extremos en 1 y 29 km
#
# **Decisión**:
#
# Los valores extremos detectados en `DailyRate`, `MonthlyIncome` y `DistanceFromHome` se mantienen sin modificación al considerarse plausibles en el contexto de RRHH, representar casos reales y tener un porcentaje bajo, evitando así la pérdida de información potencialmente relevante para el análisis de attrition.
#
# ---
#
# ### 🔗 9. Análisis de correlación entre variables numéricas
#
# - Se detectaron pares de variables altamente correlacionadas (r > 0.8), que podrían ser redundantes.
# - **Decisión**: evaluar eliminación o combinación priorizando interpretabilidad y estabilidad del modelo.
#
# ---
#
# ### 📊 10. Escalas ordinales compartidas y mapeo de encuestas
#
# Se identificaron variables que utilizan la misma escala ordinal (1 a 4) para encuestas internas:
#
# - `EnvironmentSatisfaction`
# - `JobSatisfaction`
# - `WorkLifeBalance`
# - `JobInvolvement`
# - `RelationshipSatisfaction`
# - `PerformanceRating`
#
# **Decisión**: aplicar el siguiente mapeo semántico consistente en todas ellas:
#
# - 1 → Nada satisfecho
# - 2 → Insatisfecho
# - 3 → Satisfecho
# - 4 → Muy satisfecho
#
# ---
