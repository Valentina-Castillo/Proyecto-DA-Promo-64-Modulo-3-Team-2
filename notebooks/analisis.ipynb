# %%
# 1. IDENTIFICACIÓN 
id_column = ['ID'] 

# 2. SOCIODEMOGRÁFICAS (Quién es el empleado)
sociodemograficas = [
    'Age', 
    'Gender', 
    'MaritalStatus', 
    'Education', 
    'EducationField', 
    'NumCompaniesWorked', 
    'TotalWorkingYears'
]

# 3. LABORALES / PUESTO ACTUAL (Qué hace y dónde)
laborales_puesto = [
    'Department', 
    'JobRole', 
    'JobLevel', 
    'BusinessTravel', 
    'OverTime', 
    'TrainingTimesLastYear',
    'DistanceFromHome'
]

# 4. ECONÓMICAS Y COMPENSACIÓN (Cuánto gana y extras)
economicas = [
    'MonthlyIncome', 
    'MonthlyRate', 
    'DailyRate', 
    'HourlyRate', 
    'PercentSalaryHike', 
    'StockOptionLevel'
]

# 5. FIDELIDAD Y TRAYECTORIA (Su historia en esta empresa)
trayectoria_interna = [
    'YearsAtCompany', 
    'YearsInCurrentRole', 
    'YearsSinceLastPromotion', 
    'YearsWithCurrManager'
]

# 6. PSICOMÉTRICAS / ENCUESTAS (Satisfacción y percepción)
# Escalas de 1 a 4 
encuestas_satisfaccion = [
    'EnvironmentSatisfaction', 
    'JobInvolvement', 
    'JobSatisfaction', 
    'RelationshipSatisfaction', 
    'WorkLifeBalance',
    'PerformanceRating'
]

# 7. VARIABLE OBJETIVO (Target)
target = ['Attrition']
