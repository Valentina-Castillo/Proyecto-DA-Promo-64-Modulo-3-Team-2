# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('hr.csv')

# %%
def eda_revision_completa(df):
    """ EDA avanzada para revisión rápida de DataFrames con: 
        - Estadísticas numéricas y categóricas 
        - Alertas de calidad y outliers 
        - Granularidad de nulos 
        - Sugerencias de mapeo para escalas ordinales 1-4 
        """
    filas, columnas = df.shape
    print("📐 DIMENSIONES Y DUPLICADOS")
    print(f"Filas: {filas} | Columnas: {columnas}")
    duplicados = df.duplicated().sum()
    print(f"Filas duplicadas: {duplicados} ({duplicados/filas*100:.2f}%)")
    print("-"*50)

    # ----------------------------
    # Calidad de columnas
    # ----------------------------
    print("🚑 CALIDAD DE COLUMNAS")
    calidad = pd.DataFrame({
        'Tipo': df.dtypes,
        'Nulos': df.isnull().sum(),
        '% Nulos': (df.isnull().sum() / filas * 100).round(2),
        'Valores Únicos': df.nunique(),
        '% Cardinalidad': (df.nunique() / filas * 100).round(2)
    })
    display(calidad)
    
    # Granularidad de nulos
    print("\n📌 NULOS - RESUMEN POR UMBRALES")
    umbrales = [0, 10, 25, 50, 75, 90]
    for umbral in umbrales:
        cols = calidad[calidad['% Nulos'] > umbral].index.tolist()
        if cols:
            print(f"- Columnas con >{umbral}% nulos: {cols}")

    # ----------------------------
    # Alertas de calidad
    # ----------------------------
    print("\n🚨 ALERTAS DE CALIDAD")
    constantes = calidad[calidad['Valores Únicos']==1].index.tolist()
    if constantes:
        print(f"⚠️ Columnas sin variación (se pueden eliminar): {constantes}")
    posibles_ids = calidad[calidad['% Cardinalidad']>95].index.tolist()
    if posibles_ids:
        print(f"🆔 Posibles IDs o índices: {posibles_ids}")
    cols_cat = df.select_dtypes(include=['object','category']).columns
    for col in cols_cat:
        rare = df[col].value_counts(normalize=True) < 0.05
        if rare.any():
            print(f"🎯 {col} tiene categorías raras (<5% de ocurrencias): {list(rare[rare].index)}")

    # ----------------------------
    # Estadísticas numéricas
    # ----------------------------
    print("\n📊 ESTADÍSTICAS NUMÉRICAS")
    num_cols = df.select_dtypes(include=['int64','float64']).columns
    display(df[num_cols].describe().T)

    print("\n⚠️ DETECCIÓN DE OUTLIERS (IQR 1.5x)")
    for col in num_cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        outliers = df[(df[col] < Q1 - 1.5*IQR) | (df[col] > Q3 + 1.5*IQR)][col].count()
        if outliers > 0:
            print(f"- {col}: {outliers} outliers ({outliers/filas*100:.2f}%)")

    # ----------------------------
    # Estadísticas categóricas
    # ----------------------------
    print("\n🔤 ESTADÍSTICAS CATEGÓRICAS")
    if len(cols_cat) > 0:
        desc_cat = df[cols_cat].describe().T
        display(desc_cat)
        for col in cols_cat:
            print(f"- {col} top 3 valores:")
            vc = df[col].value_counts(dropna=False)
            print(vc.head(3).to_dict())
            print("")

    # ----------------------------
    # Sugerencias de mapeo para escalas ordinales 1-4
    # ----------------------------
    print("\n💡 SUGERENCIAS DE MAPEO PARA ESCALAS 1-4")
    escala_map = {1:'Muy Insatisfecho',2:'Insatisfecho',3:'Satisfecho',4:'Muy Satisfecho'}
    cols_ordinales = [col for col in num_cols if set(df[col].dropna().unique()).issubset({1,2,3,4})]
    if cols_ordinales:
        print(f"Columnas sugeridas para mapear: {cols_ordinales}")
        print("Escala sugerida:")
        for val,label in escala_map.items():
            print(f"{val} -> {label}")
    else:
        print("No se detectaron columnas con escala 1-4 para mapear.")

    print("\n🏁 REVISIÓN COMPLETA FINALIZADA")

# %%
eda_revision_completa(df)
# Out:
# 📐 DIMENSIONES Y DUPLICADOS
# Filas: 1474 | Columnas: 35
# Filas duplicadas: 4 (0.27%)
# --------------------------------------------------
# 🚑 CALIDAD DE COLUMNAS
#                              Tipo  Nulos  % Nulos  Valores Únicos  \
# Age                       float64     73     4.95              43
# Attrition                  object      0     0.00               2
# BusinessTravel             object    117     7.94               3
# DailyRate                   int64      0     0.00             886
# Department                 object     29     1.97               3
# DistanceFromHome            int64      0     0.00              29
# Education                   int64      0     0.00               5
# EducationField             object     58     3.93               6
# EmployeeCount               int64      0     0.00               1
# EmployeeNumber              int64      0     0.00            1470
# EnvironmentSatisfaction     int64      0     0.00               4
# Gender                     object      0     0.00               2
# HourlyRate                  int64      0     0.00              71
# JobInvolvement              int64      0     0.00               4
# JobLevel                    int64      0     0.00               5
# JobRole                    object      0     0.00               9
# JobSatisfaction           float64     29     1.97               4
# MaritalStatus              object    132     8.96               4
# MonthlyIncome             float64     14     0.95            1336
# MonthlyRate                 int64      0     0.00            1427
# NumCompaniesWorked          int64      0     0.00              10
# Over18                     object      0     0.00               1
# OverTime                   object     44     2.99               2
# PercentSalaryHike           int64      0     0.00              15
# PerformanceRating           int64      0     0.00               2
# RelationshipSatisfaction    int64      0     0.00               4
# StandardHours             float64    164    11.13               1
# StockOptionLevel            int64      0     0.00               4
# TotalWorkingYears           int64      0     0.00              40
# TrainingTimesLastYear     float64     88     5.97               7
# WorkLifeBalance             int64      0     0.00               4
# YearsAtCompany              int64      0     0.00              37
# YearsInCurrentRole          int64      0     0.00              19
# YearsSinceLastPromotion     int64      0     0.00              16
# YearsWithCurrManager      float64    148    10.04              18
#
#                           % Cardinalidad
# Age                                 2.92
# Attrition                           0.14
# BusinessTravel                      0.20
# DailyRate                          60.11
# Department                          0.20
# DistanceFromHome                    1.97
# Education                           0.34
# EducationField                      0.41
# EmployeeCount                       0.07
# EmployeeNumber                     99.73
# EnvironmentSatisfaction             0.27
# Gender                              0.14
# HourlyRate                          4.82
# JobInvolvement                      0.27
# JobLevel                            0.34
# JobRole                             0.61
# JobSatisfaction                     0.27
# MaritalStatus                       0.27
# MonthlyIncome                      90.64
# MonthlyRate                        96.81
# NumCompaniesWorked                  0.68
# Over18                              0.07
# OverTime                            0.14
# PercentSalaryHike                   1.02
# PerformanceRating                   0.14
# RelationshipSatisfaction            0.27
# StandardHours                       0.07
# StockOptionLevel                    0.27
# TotalWorkingYears                   2.71
# TrainingTimesLastYear               0.47
# WorkLifeBalance                     0.27
# YearsAtCompany                      2.51
# YearsInCurrentRole                  1.29
# YearsSinceLastPromotion             1.09
# YearsWithCurrManager                1.22
# 📌 NULOS - RESUMEN POR UMBRALES
# - Columnas con >0% nulos: ['Age', 'BusinessTravel', 'Department', 'EducationField', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'OverTime', 'StandardHours', 'TrainingTimesLastYear', 'YearsWithCurrManager']
# - Columnas con >10% nulos: ['StandardHours', 'YearsWithCurrManager']
#
# 🚨 ALERTAS DE CALIDAD
# ⚠️ Columnas sin variación (se pueden eliminar): ['EmployeeCount', 'Over18', 'StandardHours']
# 🆔 Posibles IDs o índices: ['EmployeeNumber', 'MonthlyRate']
# 🎯 Department tiene categorías raras (<5% de ocurrencias): ['Human Resources']
# 🎯 EducationField tiene categorías raras (<5% de ocurrencias): ['Human Resources']
# 🎯 JobRole tiene categorías raras (<5% de ocurrencias): [' hUMAN rESOURCES ']
# 🎯 MaritalStatus tiene categorías raras (<5% de ocurrencias): ['Marreid']
#
# 📊 ESTADÍSTICAS NUMÉRICAS
#                            count          mean          std     min      25%  \
# Age                       1401.0     36.944325     9.105009    18.0    30.00
# DailyRate                 1474.0    802.702171   403.539530   102.0   465.00
# DistanceFromHome          1474.0      9.199457     8.104266     1.0     2.00
# Education                 1474.0      2.911126     1.024267     1.0     2.00
# EmployeeCount             1474.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1474.0   1024.471506   602.421193     1.0   488.75
# EnvironmentSatisfaction   1474.0      2.723881     1.093280     1.0     2.00
# HourlyRate                1474.0     65.887381    20.310444    30.0    48.00
# JobInvolvement            1474.0      2.729986     0.712861     1.0     2.00
# JobLevel                  1474.0      2.063772     1.106055     1.0     1.00
# JobSatisfaction           1445.0      2.728720     1.106409     1.0     2.00
# MonthlyIncome             1460.0   6497.448630  4706.059294  1009.0  2909.00
# MonthlyRate               1474.0  14328.611940  7120.225285  2094.0  8054.50
# NumCompaniesWorked        1474.0      2.688602     2.496443     0.0     1.00
# PercentSalaryHike         1474.0     15.206920     3.659274    11.0    12.00
# PerformanceRating         1474.0      3.153324     0.360422     3.0     3.00
# RelationshipSatisfaction  1474.0      2.713704     1.080338     1.0     2.00
# StandardHours             1310.0     80.000000     0.000000    80.0    80.00
# StockOptionLevel          1474.0      0.794437     0.851784     0.0     0.00
# TotalWorkingYears         1474.0     11.274084     7.785972     0.0     6.00
# TrainingTimesLastYear     1386.0      2.797980     1.296882     0.0     2.00
# WorkLifeBalance           1474.0      2.761872     0.705625     1.0     2.00
# YearsAtCompany            1474.0      6.996608     6.122920     0.0     3.00
# YearsInCurrentRole        1474.0      4.221845     3.622032     0.0     2.00
# YearsSinceLastPromotion   1474.0      2.183175     3.219356     0.0     0.00
# YearsWithCurrManager      1326.0      4.061840     3.517603     0.0     2.00
#
#                               50%       75%      max
# Age                          36.0     43.00     60.0
# DailyRate                   803.0   1157.00   1499.0
# DistanceFromHome              7.0     14.00     29.0
# Education                     3.0      4.00      5.0
# EmployeeCount                 1.0      1.00      1.0
# EmployeeNumber             1020.5   1555.75   2068.0
# EnvironmentSatisfaction       3.0      4.00      4.0
# HourlyRate                   66.0     83.75    100.0
# JobInvolvement                3.0      3.00      4.0
# JobLevel                      2.0      3.00      5.0
# JobSatisfaction               3.0      4.00      4.0
# MonthlyIncome              4907.0   8377.00  19999.0
# MonthlyRate               14248.5  20465.75  26999.0
# NumCompaniesWorked            2.0      4.00      9.0
# PercentSalaryHike            14.0     18.00     25.0
# PerformanceRating             3.0      3.00      4.0
# RelationshipSatisfaction      3.0      4.00      4.0
# StandardHours                80.0     80.00     80.0
# StockOptionLevel              1.0      1.00      3.0
# TotalWorkingYears            10.0     15.00     40.0
# TrainingTimesLastYear         3.0      3.00      6.0
# WorkLifeBalance               3.0      3.00      4.0
# YearsAtCompany                5.0      9.00     40.0
# YearsInCurrentRole            3.0      7.00     18.0
# YearsSinceLastPromotion       1.0      3.00     15.0
# YearsWithCurrManager          3.0      7.00     17.0
# ⚠️ DETECCIÓN DE OUTLIERS (IQR 1.5x)
# - MonthlyIncome: 113 outliers (7.67%)
# - NumCompaniesWorked: 52 outliers (3.53%)
# - PerformanceRating: 226 outliers (15.33%)
# - StockOptionLevel: 85 outliers (5.77%)
# - TotalWorkingYears: 63 outliers (4.27%)
# - TrainingTimesLastYear: 227 outliers (15.40%)
# - YearsAtCompany: 104 outliers (7.06%)
# - YearsInCurrentRole: 21 outliers (1.42%)
# - YearsSinceLastPromotion: 107 outliers (7.26%)
# - YearsWithCurrManager: 12 outliers (0.81%)
#
# 🔤 ESTADÍSTICAS CATEGÓRICAS
#                count unique                     top  freq
# Attrition       1474      2                      No  1236
# BusinessTravel  1357      3           Travel_Rarely   955
# Department      1445      3  Research & Development   941
# EducationField  1416      6           Life Sciences   582
# Gender          1474      2                    Male   885
# JobRole         1474      9        sALES eXECUTIVE    327
# MaritalStatus   1342      4                 Married   604
# Over18          1474      1                       Y  1474
# OverTime        1430      2                      No  1025
# - Attrition top 3 valores:
# {'No': 1236, 'Yes': 238}
#
# - BusinessTravel top 3 valores:
# {'Travel_Rarely': 955, 'Travel_Frequently': 263, 'Non-Travel': 139}
#
# - Department top 3 valores:
# {'Research & Development': 941, 'Sales': 440, 'Human Resources': 64}
#
# - EducationField top 3 valores:
# {'Life Sciences': 582, 'Medical': 449, 'Marketing': 152}
#
# - Gender top 3 valores:
# {'Male': 885, 'Female': 589}
#
# - JobRole top 3 valores:
# {' sALES eXECUTIVE ': 327, ' rESEARCH sCIENTIST ': 293, ' lABORATORY tECHNICIAN ': 259}
#
# - MaritalStatus top 3 valores:
# {'Married': 604, 'Single': 437, 'Divorced': 298}
#
# - Over18 top 3 valores:
# {'Y': 1474}
#
# - OverTime top 3 valores:
# {'No': 1025, 'Yes': 405, nan: 44}
#
#
# 💡 SUGERENCIAS DE MAPEO PARA ESCALAS 1-4
# Columnas sugeridas para mapear: ['EmployeeCount', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobSatisfaction', 'PerformanceRating', 'RelationshipSatisfaction', 'WorkLifeBalance']
# Escala sugerida:
# 1 -> Muy Insatisfecho
# 2 -> Insatisfecho
# 3 -> Satisfecho
# 4 -> Muy Satisfecho
#
# 🏁 REVISIÓN COMPLETA FINALIZADA

# %%
# Limpieza específica del dataset
df.set_index(['EmployeeNumber'], inplace = True)
df.index.name = 'ID'
df.drop("Over18", axis = 1, inplace = True)
df.drop("StandardHours", axis = 1, inplace = True)
df.drop("EmployeeCount", axis = 1, inplace = True)
df = df.astype({'Age': 'Int64', 'DailyRate': float, 'HourlyRate': float, 'JobSatisfaction': 'Int64', 'MonthlyRate': float, 'TrainingTimesLastYear': 'Int64', 'YearsWithCurrManager': 'Int64'})
df['MaritalStatus'] = df['MaritalStatus'].str.replace('Marreid', 'Married')
df['JobRole'] = df['JobRole'].str.strip().str.title()
df['BusinessTravel'] = df['BusinessTravel'].str.replace('Travel_Rarely', 'Rarely').str.replace('Travel_Frequently', 'Frequently').str.replace('Non-Travel', 'Non')

# %%
df.head()
# Out:
#     Age Attrition BusinessTravel  DailyRate              Department  \
# ID
# 1    41       Yes         Rarely     1102.0                   Sales
# 2    49        No     Frequently      279.0  Research & Development
# 4    37       Yes         Rarely     1373.0  Research & Development
# 5    33        No     Frequently     1392.0  Research & Development
# 7    27        No         Rarely      591.0  Research & Development
#
#     DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ID
# 1                  1          2  Life Sciences                        2
# 2                  8          1  Life Sciences                        3
# 4                  2          2          Other                        4
# 5                  3          4  Life Sciences                        4
# 7                  2          1        Medical                        1
#
#     Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# ID          ...
# 1   Female  ...                  3                         1
# 2     Male  ...                  4                         4
# 4     Male  ...                  3                         2
# 5   Female  ...                  3                         3
# 7     Male  ...                  3                         4
#
#     StockOptionLevel TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# ID
# 1                  0                 8                      0               1
# 2                  1                10                      3               3
# 4                  0                 7                      3               3
# 5                  0                 8                      3               3
# 7                  1                 6                      3               3
#
#     YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# ID
# 1                6                   4                        0
# 2               10                   7                        1
# 4                0                   0                        0
# 5                8                   7                        3
# 7                2                   2                        2
#
#    YearsWithCurrManager
# ID
# 1                     5
# 2                     7
# 4                     0
# 5                     0
# 7                     2
#
# [5 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')
